# %%
import json

# %%
def clean_data(data):
    #Remove missing names
    data["users"] = [ user for user in data["users"] if user["name"].strip()]

    #Remove duplicate values
    for user in data["users"]:
        user["friends"] = list(set(user["friends"]))

    #Remove user name which is not active:
    data["users"] = [user for user in data["users"] if user["friends"] or user["liked_pages"]]

    #Remove dulpicate id :
    unique_pages = {}
    for page in data["pages"]:
        unique_pages[page["id"]] = page
    data["pages"] =  list(unique_pages.values())   
    return data

#load data and create a new standardize data format
data = json.load(open("data2.json"))
data = clean_data(data)
json.dump(data,open("Clean_file.json","w"),indent = 4)
print("Data sucessfully clean and save in file")
# Out:
# Data sucessfully clean and save in file
